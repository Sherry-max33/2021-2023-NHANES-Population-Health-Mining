# %%
import sys
sys.path.append("/Users/sherrywang") 

from nhanes_Processing_1 import build_nhanes_2021_2023

path = "/Users/sherrywang/Desktop/Projects/Dataset"
nhanes = build_nhanes_2021_2023(path)
# Out:
# ✅ NHANES dataset saved to: /Users/sherrywang/Desktop/Data_Mining/Project/data-mining-project-starter/data/processed/nhanes.csv
